# %%
import yfinance as yf
import numpy as np

# %%
tickers = ["MSFT", "AMZN"]
ohlcv_data = {}

for ticker in tickers:
  temp = yf.download(ticker, period = '1mo', interval = '5m')
  temp.dropna(how = 'any', inplace = True)
  ohlcv_data[ticker] = temp

def RSI(DF, n=14):
  df = DF.copy()
  df["change"] = df["Adj Close"] - df["Adj Close"].shift(1)
  df["gain"] = np.where(df["change"]>=0, df["change"], 0)
  df["loss"] = np.where(df["change"]<0, -1*df["change"], 0)
  df["avgGain"] = df["gain"].ewm(alpha=1/n, min_periods=n).mean()
  df["avgLoss"] = df["loss"].ewm(alpha=1/n, min_periods=n).mean()
  df["rs"] = df["avgGain"]/df["avgLoss"]
  df["rsi"] = 100 - (100/(1+df["rs"]))
  return df["rsi"]

for ticker in tickers:
  ohlcv_data[ticker]["RSI"] = RSI(ohlcv_data[ticker])
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
print(ohlcv_data)
# Out:
# {'MSFT':                                  Open        High         Low       Close  \
# Datetime
# 2024-06-25 09:30:00-04:00  448.029999  449.000000  447.000000  447.719910
# 2024-06-25 09:35:00-04:00  447.579987  448.355011  446.880005  447.589996
# 2024-06-25 09:40:00-04:00  447.554993  447.609985  446.750000  447.019989
# 2024-06-25 09:45:00-04:00  446.929993  448.549988  446.899994  447.750000
# 2024-06-25 09:50:00-04:00  447.760010  448.016388  447.359985  447.769989
# ...                               ...         ...         ...         ...
# 2024-07-24 15:35:00-04:00  429.209991  429.230011  428.519989  429.086914
# 2024-07-24 15:40:00-04:00  429.149994  429.670013  429.135010  429.230011
# 2024-07-24 15:45:00-04:00  429.239990  429.609985  428.799988  429.329987
# 2024-07-24 15:50:00-04:00  429.410004  429.869995  428.385010  428.440002
# 2024-07-24 15:55:00-04:00  428.440002  429.309998  427.730011  428.940002
#
#                             Adj Close   Volume        RSI
# Datetime
# 2024-06-25 09:30:00-04:00  447.719910   875310        NaN
# 2024-06-25 09:35:00-04:00  447.589996   268991        NaN
# 2024-06-25 09:40:00-04:00  447.019989   227823        NaN
# 2024-06-25 09:45:00-04:00  447.750000   204711        NaN
# 2024-06-25 09:50:00-04:00  447.769989   102348        NaN
# ...                               ...      ...        ...
# 2024-07-24 15:35:00-04:00  429.086914   296140  48.882913
# 2024-07-24 15:40:00-04:00  429.230011   236120  50.136001
# 2024-07-24 15:45:00-04:00  429.329987   306069  51.039054
# 2024-07-24 15:50:00-04:00  428.440002   588599  43.488573
# 2024-07-24 15:55:00-04:00  428.940002  1586859  48.131071
#
# [1602 rows x 7 columns], 'AMZN':                                  Open        High         Low       Close  \
# Datetime
# 2024-06-25 09:30:00-04:00  186.820007  187.289993  186.169998  186.690002
# 2024-06-25 09:35:00-04:00  186.639999  186.750000  185.889999  186.199905
# 2024-06-25 09:40:00-04:00  186.181107  187.000000  186.130005  186.735001
# 2024-06-25 09:45:00-04:00  186.710007  186.940002  186.509995  186.514999
# 2024-06-25 09:50:00-04:00  186.559998  186.899994  186.490097  186.880005
# ...                               ...         ...         ...         ...
# 2024-07-24 15:35:00-04:00  181.185104  181.345001  181.010101  181.195007
# 2024-07-24 15:40:00-04:00  181.199997  181.410004  181.039993  181.059998
# 2024-07-24 15:45:00-04:00  181.054993  181.281998  180.800003  181.210007
# 2024-07-24 15:50:00-04:00  181.199997  181.389999  180.630005  180.630005
# 2024-07-24 15:55:00-04:00  180.634995  181.020004  180.410004  180.860001
#
#                             Adj Close   Volume        RSI
# Datetime
# 2024-06-25 09:30:00-04:00  186.690002  1664278        NaN
# 2024-06-25 09:35:00-04:00  186.199905   594791        NaN
# 2024-06-25 09:40:00-04:00  186.735001   410322        NaN
# 2024-06-25 09:45:00-04:00  186.514999   316819        NaN
# 2024-06-25 09:50:00-04:00  186.880005   322973        NaN
# ...                               ...      ...        ...
# 2024-07-24 15:35:00-04:00  181.195007   387326  42.210563
# 2024-07-24 15:40:00-04:00  181.059998   411298  39.144270
# 2024-07-24 15:45:00-04:00  181.210007   537872  44.010951
# 2024-07-24 15:50:00-04:00  180.630005   927767  33.016781
# 2024-07-24 15:55:00-04:00  180.860001  2224121  39.473641
#
# [1602 rows x 7 columns]}
