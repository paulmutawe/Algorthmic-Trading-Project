# %%
import yfinance as yf
import pandas as pd
import numpy as np

# %%
tickers = ["AMZN", "GOOG", "MSFT", "TSLA"]
ohlcv_data = {}

# %%
for ticker in tickers:
  temp = yf.download(ticker, period = '6mo', interval = '1d')
  temp.dropna(how="any", inplace=True)
  ohlcv_data[ticker] = temp
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
def CAGR(DF):
    "function to calculate the Cumulative Annual Growth Rate of a trading strategy"
    df = DF.copy()
    df["return"] = DF["Adj Close"].pct_change()
    df["cum_return"] = (1 + df["return"]).cumprod()
    n = len(df)/252
    CAGR = (df["cum_return"][-1])**(1/n) - 1
    return CAGR

def volatility(DF):
    "function to calculate annualized volatility of a trading strategy"
    df = DF.copy()
    df["return"] = df["Adj Close"].pct_change()
    vol = df["return"].std() * np.sqrt(252)
    return vol

# %%
def sharpe (DF, rf):
  df = DF.copy()
  return (CAGR(df) - rf)/volatility(df)

# %%
def sortino(DF, rf):
  df = DF.copy()
  df["return"] = df["Adj Close"].pct_change()
  neg_return = np.where(df["return"]>0, 0, df["return"])
  neg_vol = np.sqrt((pd.Series(neg_return[neg_return != 0]) ** 2).mean() * 252)
  return (CAGR(df) - rf)/neg_vol

# %%
for ticker in ohlcv_data:
  print ("Sharpe of {} = {}".format(ticker, sharpe (ohlcv_data[ticker], 0.03)))
  print ("Sortino of {} = {}".format(ticker, sortino(ohlcv_data[ticker], 0.03)))
# Out:
# Sharpe of AMZN = -0.01513558294058267
# Sortino of AMZN = -0.014758966691162861
# Sharpe of GOOG = 0.4378381076674033
# Sortino of GOOG = 0.3913671561669241
# Sharpe of MSFT = -0.19312280200512555
# Sortino of MSFT = -0.17142757340474227
# Sharpe of TSLA = 1.845993541018566
# Sortino of TSLA = 2.028338865243676
# <ipython-input-17-6aedfac07e2c>:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   CAGR = (df["cum_return"][-1])**(1/n) - 1
# <ipython-input-17-6aedfac07e2c>:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   CAGR = (df["cum_return"][-1])**(1/n) - 1
# <ipython-input-17-6aedfac07e2c>:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   CAGR = (df["cum_return"][-1])**(1/n) - 1
# <ipython-input-17-6aedfac07e2c>:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   CAGR = (df["cum_return"][-1])**(1/n) - 1
# <ipython-input-17-6aedfac07e2c>:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   CAGR = (df["cum_return"][-1])**(1/n) - 1
# <ipython-input-17-6aedfac07e2c>:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   CAGR = (df["cum_return"][-1])**(1/n) - 1
# <ipython-input-17-6aedfac07e2c>:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   CAGR = (df["cum_return"][-1])**(1/n) - 1
# <ipython-input-17-6aedfac07e2c>:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   CAGR = (df["cum_return"][-1])**(1/n) - 1
