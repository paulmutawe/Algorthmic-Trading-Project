# %%
import yfinance as yf

# %%
tickers = ["AMZN", "MSFT"]
ohlcv_data = {}

# %%
for ticker in tickers:
  temp = yf.download(ticker, period = '1mo', interval = "5m")
  temp.dropna(how = "any", inplace = True)
  ohlcv_data[ticker] = temp
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
def ATR(DF, n=14):
  df = DF.copy()
  df["H-L"] = df["High"] - df["Low"]
  df["H-PC"] = df["High"] - df["Adj Close"].shift(1)
  df["L-PC"] = df["Low"] - df["Adj Close"].shift(1)
  df["TR"] = df[["H-L", "H-PC", "L-PC"]].max(axis = 1, skipna = False)
  df["ATR"] = df["TR"].ewm(com = n, min_periods = n).mean()
  return df["ATR"]

# %%
for ticker in ohlcv_data:
  ohlcv_data[ticker]["ATR"] = ATR(ohlcv_data[ticker])

# %%
print(ohlcv_data)
# Out:
# {'AMZN':                                  Open        High         Low       Close  \
# Datetime
# 2024-06-12 09:30:00-04:00  188.119995  188.119995  185.940002  187.350006
# 2024-06-12 09:35:00-04:00  187.367493  188.250000  186.880005  187.630005
# 2024-06-12 09:40:00-04:00  187.613495  187.854996  187.070099  187.199997
# 2024-06-12 09:45:00-04:00  187.270004  187.440002  186.867493  187.389999
# 2024-06-12 09:50:00-04:00  187.410004  187.820007  187.339996  187.639999
# ...                               ...         ...         ...         ...
# 2024-07-11 15:35:00-04:00  194.167404  194.869995  194.167404  194.860001
# 2024-07-11 15:40:00-04:00  194.854996  194.869995  194.369995  194.405304
# 2024-07-11 15:45:00-04:00  194.410004  194.679993  194.360001  194.589996
# 2024-07-11 15:50:00-04:00  194.600006  195.149994  194.589996  194.960007
# 2024-07-11 15:55:00-04:00  194.960007  195.199997  194.669998  195.054993
#
#                             Adj Close   Volume       ATR
# Datetime
# 2024-06-12 09:30:00-04:00  187.350006  2672711       NaN
# 2024-06-12 09:35:00-04:00  187.630005   820898       NaN
# 2024-06-12 09:40:00-04:00  187.199997   736456       NaN
# 2024-06-12 09:45:00-04:00  187.389999   537914       NaN
# 2024-06-12 09:50:00-04:00  187.639999   566436       NaN
# ...                               ...      ...       ...
# 2024-07-11 15:35:00-04:00  194.860001   400300  0.374596
# 2024-07-11 15:40:00-04:00  194.405304   357217  0.382956
# 2024-07-11 15:45:00-04:00  194.589996   370457  0.378758
# 2024-07-11 15:50:00-04:00  194.960007   893521  0.390841
# 2024-07-11 15:55:00-04:00  195.054993  1985601  0.400118
#
# [1524 rows x 7 columns], 'MSFT':                                  Open        High         Low       Close  \
# Datetime
# 2024-06-12 09:30:00-04:00  435.320007  436.579987  433.250000  436.169891
# 2024-06-12 09:35:00-04:00  436.086609  436.346008  434.619995  435.690002
# 2024-06-12 09:40:00-04:00  435.617188  436.649994  435.359985  436.559998
# 2024-06-12 09:45:00-04:00  436.649994  437.600006  436.570007  437.522797
# 2024-06-12 09:50:00-04:00  437.540009  438.500000  437.440002  438.209991
# ...                               ...         ...         ...         ...
# 2024-07-11 15:35:00-04:00  454.660095  455.690002  454.660004  455.470001
# 2024-07-11 15:40:00-04:00  455.454987  455.470001  454.670013  454.670013
# 2024-07-11 15:45:00-04:00  454.660004  455.350006  454.644989  455.107513
# 2024-07-11 15:50:00-04:00  455.190002  455.899994  455.084991  455.230103
# 2024-07-11 15:55:00-04:00  455.260010  455.790009  454.670013  454.709991
#
#                             Adj Close   Volume       ATR
# Datetime
# 2024-06-12 09:30:00-04:00  436.169891  1521701       NaN
# 2024-06-12 09:35:00-04:00  435.690002   368642       NaN
# 2024-06-12 09:40:00-04:00  436.559998   312135       NaN
# 2024-06-12 09:45:00-04:00  437.522797   388223       NaN
# 2024-06-12 09:50:00-04:00  438.209991   394281       NaN
# ...                               ...      ...       ...
# 2024-07-11 15:35:00-04:00  455.470001   162643  0.645703
# 2024-07-11 15:40:00-04:00  454.670013   157078  0.655989
# 2024-07-11 15:45:00-04:00  455.107513   184014  0.659258
# 2024-07-11 15:50:00-04:00  455.230103   422556  0.669641
# 2024-07-11 15:55:00-04:00  454.709991  1164833  0.699664
#
# [1524 rows x 7 columns]}
